# %%
# ====================================================
# DEMO CODE for pypi package drugsideeffect
# ====================================================

# %%
# ==========================================================
# DEMO CODE for  pypi package drugsideeffect
# ==========================================================

# ---- STEP 1: INSTALL PACKAGE (FROM OFFICIAL PYPI) ----
# !pip install --upgrade drugsideeffect

# ---- STEP 2: IMPORT LIBRARIES ----
import warnings
warnings.filterwarnings("ignore")

import pandas as pd

# ---- STEP 3: LOAD DATA ----
try:
    df = pd.read_csv(r"C:\Users\91990\Desktop\data.csv")
    print("Dataset loaded successfully")
    print(df.head())
except Exception as e:
    print("Error loading dataset:", e)
    raise

# ---- STEP 4: IMPORT PACKAGE ----
try:
    from drugsideeffect.processing import main
    from drugsideeffect.visualization import (
        plot_symptom_extraction,
        plot_day_of_week_distribution,
        plot_data_count_per_month,
        plot_sentiment_distribution,
        plot_create_side_effects_correlation,
        plot_create_side_effects_visualizations,
        plot_visualize,
        plot_known_symptoms,
        plot_uncommon_side_effects_pie_chart,
        plot_proportion_of_english_words
    )
    print("Package imported successfully")

except Exception as e:
    print("Import error:", e)
    print("Fix: reinstall package or check installed version on PyPI")
    raise

# ---- STEP 5: FEATURE EXTRACTION ----
print("\n Running symptom extraction...")
plot_symptom_extraction(df)

# ---- STEP 6: BASIC ANALYSIS ----
print("\n Running basic analytics...")
plot_day_of_week_distribution(df)
plot_data_count_per_month(df)
plot_sentiment_distribution(df)

# ---- STEP 7: ADVANCED PHARMACOVIGILANCE ANALYSIS ----
print("\n Running pharmacovigilance visualization...")
plot_create_side_effects_correlation(df)
plot_create_side_effects_visualizations(df)
plot_visualize(df)

# ---- STEP 8: SYMPTOM + DATA QUALITY ANALYSIS ----
print("\n Running symptom & data quality analysis...")
plot_known_symptoms(df)
plot_uncommon_side_effects_pie_chart(df)
plot_proportion_of_english_words(df)

print("\nALL VISUALIZATION COMPLETED")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: drugsideeffect in c:\users\91990\appdata\roaming\python\python313\site-packages (0.1.4)
# Requirement already satisfied: pandas>=1.5 in c:\programdata\anaconda3\lib\site-packages (from drugsideeffect) (2.3.3)
# Requirement already satisfied: numpy>=1.23 in c:\programdata\anaconda3\lib\site-packages (from drugsideeffect) (2.3.5)
# Requirement already satisfied: matplotlib>=3.6 in c:\programdata\anaconda3\lib\site-packages (from drugsideeffect) (3.10.6)
# Requirement already satisfied: seaborn>=0.12 in c:\programdata\anaconda3\lib\site-packages (from drugsideeffect) (0.13.2)
# Requirement already satisfied: plotly>=5.11 in c:\programdata\anaconda3\lib\site-packages (from drugsideeffect) (6.3.0)
# Requirement already satisfied: nltk>=3.8 in c:\programdata\anaconda3\lib\site-packages (from drugsideeffect) (3.9.2)
# Requirement already satisfied: textblob>=0.10 in c:\users\91990\appdata\roaming\python\python313\site-packages (from drugsideeffect) (0.20.0)
# Requirement already satisfied: spacy>=3.5 in c:\users\91990\appdata\roaming\python\python313\site-packages (from drugsideeffect) (3.8.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.6->drugsideeffect) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.6->drugsideeffect) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.6->drugsideeffect) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.6->drugsideeffect) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.6->drugsideeffect) (25.0)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.6->drugsideeffect) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.6->drugsideeffect) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.6->drugsideeffect) (2.9.0.post0)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.8->drugsideeffect) (8.2.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.8->drugsideeffect) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.8->drugsideeffect) (2025.9.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.8->drugsideeffect) (4.67.1)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.5->drugsideeffect) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.5->drugsideeffect) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\programdata\anaconda3\lib\site-packages (from plotly>=5.11->drugsideeffect) (2.7.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->drugsideeffect) (1.17.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\91990\appdata\roaming\python\python313\site-packages (from spacy>=3.5->drugsideeffect) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\91990\appdata\roaming\python\python313\site-packages (from spacy>=3.5->drugsideeffect) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\91990\appdata\roaming\python\python313\site-packages (from spacy>=3.5->drugsideeffect) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\91990\appdata\roaming\python\python313\site-packages (from spacy>=3.5->drugsideeffect) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\91990\appdata\roaming\python\python313\site-packages (from spacy>=3.5->drugsideeffect) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in c:\users\91990\appdata\roaming\python\python313\site-packages (from spacy>=3.5->drugsideeffect) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\91990\appdata\roaming\python\python313\site-packages (from spacy>=3.5->drugsideeffect) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in c:\users\91990\appdata\roaming\python\python313\site-packages (from spacy>=3.5->drugsideeffect) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\91990\appdata\roaming\python\python313\site-packages (from spacy>=3.5->drugsideeffect) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in c:\users\91990\appdata\roaming\python\python313\site-packages (from spacy>=3.5->drugsideeffect) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in c:\users\91990\appdata\roaming\python\python313\site-packages (from spacy>=3.5->drugsideeffect) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from spacy>=3.5->drugsideeffect) (0.20.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from spacy>=3.5->drugsideeffect) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from spacy>=3.5->drugsideeffect) (2.12.4)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy>=3.5->drugsideeffect) (3.1.6)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy>=3.5->drugsideeffect) (80.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy>=3.5->drugsideeffect) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy>=3.5->drugsideeffect) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy>=3.5->drugsideeffect) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy>=3.5->drugsideeffect) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.5->drugsideeffect) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.5->drugsideeffect) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.5->drugsideeffect) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.5->drugsideeffect) (2025.11.12)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\91990\appdata\roaming\python\python313\site-packages (from thinc<8.4.0,>=8.3.12->spacy>=3.5->drugsideeffect) (1.3.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->nltk>=3.8->drugsideeffect) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.5->drugsideeffect) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\programdata\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.5->drugsideeffect) (14.2.0)
# Requirement already satisfied: cloudpathlib>=0.7.0 in c:\users\91990\appdata\roaming\python\python313\site-packages (from weasel<2.0.0,>=1.0.0->spacy>=3.5->drugsideeffect) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in c:\users\91990\appdata\roaming\python\python313\site-packages (from weasel<2.0.0,>=1.0.0->spacy>=3.5->drugsideeffect) (8.0.0)
# Requirement already satisfied: httpx>=0.24.0 in c:\programdata\anaconda3\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy>=3.5->drugsideeffect) (0.28.1)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy>=3.5->drugsideeffect) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy>=3.5->drugsideeffect) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy>=3.5->drugsideeffect) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.5->drugsideeffect) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.5->drugsideeffect) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.5->drugsideeffect) (0.1.2)
# Requirement already satisfied: wrapt in c:\programdata\anaconda3\lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy>=3.5->drugsideeffect) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy>=3.5->drugsideeffect) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->spacy>=3.5->drugsideeffect) (3.0.2)
# Dataset loaded successfully
#               Date  month  RT_Like  \
# 0    1/1/2024 8:10      1       12
# 1   1/3/2024 10:22      1        5
# 2   1/5/2024 14:45      1       30
# 3    1/7/2024 9:15      1        8
# 4  1/10/2024 18:30      1       45
#
#                                                 text
# 0  Day 2 after vaccination I feel fever and headache
# 1           Feeling great today no issues after dose
# 2  Heart racing and brain fog started few hours p...
# 3        Mild fatigue and muscle pain but manageable
# 4  This is serious I have chest pain and feel ver...
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\91990\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\91990\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\91990\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\91990\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Package imported successfully
#
#  Running symptom extraction...
#  Running basic analytics...
#  Running pharmacovigilance visualization...
#  Running symptom & data quality analysis...
# No uncommon symptoms found to plot.
# Proportion of English words: 93.04%
#
# ALL VISUALIZATION COMPLETED
